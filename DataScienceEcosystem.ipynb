# %% [markdown]
# # DataScienceEcosystem
# ![2-title.png](attachment:6f67257c-021a-498d-a451-e9ae064d036d.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:aa355fe7-0dc4-4f98-93a4-b1490dfd4f93.png)

# %% [markdown]
# **list the objectives that this notebook covered**
# - popular languages
# - commonly used libraries
# - data science tools
#
# ![10-objectives.png](attachment:84cc337b-6666-4d00-8dce-49793b394e07.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. SQL
# 2. Python
# 3. R
#
# ![4-dslanguages.png](attachment:44a14f5d-5f72-4714-a9a2-2f3ac16213a1.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# + Pandas
# + NumPy
# + SciPy
# + Matplotlib
# + Seaborn
#
# ![5-dslibraries.png](attachment:5f3b3379-6baa-4cf5-b18f-54b0edd8dc81.png)

# %% [markdown]
# | Data Science Tools |
# | --- |
# | Jupyter Notebook |
# | VSCode |
# | Spyder |
#
# ![6-dstools.png](attachment:551c1227-f351-40ac-bf44-21c8225fe662.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
#
# ![7-introarithmetic.png](attachment:bae9f407-df9a-45ef-a0fc-8fdb4e374e3e.png)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers.

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:caadee7f-98a9-4c15-af33-7f393fc000a8.png)

# %% [markdown]
#  This will convert 200 minutes to hours by diving by 60.

# %%
# 定义一个函数将分钟转换为小时
def minutes_to_hours(minutes):
    return minutes / 60

total_minutes = 200
hours = minutes_to_hours(total_minutes)
print(f"{total_minutes} minutes is {hours} hours.")
# Out:
# 200 minutes is 3.3333333333333335 hours.

# %% [markdown]
# ![9-hourstominutes.png](attachment:1dc1b20f-65bb-4f83-8cc7-4e92bf9287b3.png)

# %% [markdown]
# ## Author name: YuchenZHOU
# ![11-authordetails.png](attachment:7ac0b1b7-191f-47ac-97bb-a4a8a20f964b.png)
